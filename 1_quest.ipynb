# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X_train = pd.read_csv('data/preprocessed/solTrainXtrans_py.csv').values
X_test = pd.read_csv('data/preprocessed/solTestXtrans_py.csv').values

y_train = pd.read_csv('data/original/solTrainY.txt', sep='\s+').values.flatten()
y_test  = pd.read_csv('data/original/solTestY.txt', sep='\s+').values.flatten()

# %% [markdown]
# Implementando o OLS

# %%
def OLS(X_train, y_train):
    Beta = np.linalg.pinv(X_train.T @ X_train) @ X_train.T @ y_train

    return Beta

# %%
# Para Calcular os valores preditores:
X_train_new = np.c_[np.ones((X_train.shape[0], 1)), X_train]

X_test_new = np.c_[np.ones((X_test.shape[0], 1)), X_test]

B_Chapeu = OLS(X_train_new, y_train)

y_predict = X_test_new @ B_Chapeu

y_predict
# Out:
# array([ 1.13656004e+00,  2.63763210e-02, -3.87234499e-01,  1.02979072e+00,
#        -2.16771084e-01,  1.53759578e+00,  7.07452677e-01,  8.99405217e-01,
#         2.89154031e-01, -5.28659122e-01, -3.62597414e-01, -9.70555804e-01,
#         2.04087676e-02, -2.02037547e-01, -6.79368216e-01, -4.17821307e-01,
#        -1.49623629e-01,  3.75887724e-01,  3.87078009e-01, -6.44964236e-01,
#         5.68256183e-01,  2.89179819e-01, -7.00929390e-01,  2.40269031e-02,
#        -9.88190200e-01,  1.21503324e-01, -7.42279340e-01,  1.26012108e+00,
#        -1.98603201e+00, -1.10581023e+00, -2.58709443e+00, -9.67921572e-01,
#        -6.76775481e-01, -1.44209682e-01, -8.45623408e-02, -1.27108641e+00,
#         2.58724161e-01, -5.87408608e-01, -5.69394172e-03, -6.18591773e-01,
#        -8.01166735e-01, -2.17929875e+00, -1.09172890e+00, -1.59081463e-01,
#        -1.67209854e+00, -7.99278674e-01, -7.11684861e-01, -8.72236632e-01,
#        -1.19216887e+00, -9.56905714e-01,  8.51590146e-01, -1.68812277e+00,
#        -1.45826064e+00, -1.51643055e+00, -2.17389361e+00, -1.27688658e+00,
#        -1.08310895e+00, -1.52196612e+00, -1.82523095e+00, -1.40794907e+00,
#        -1.15286963e+00, -1.32639432e+00, -8.84909885e-01, -1.24153608e+00,
#        -9.55047830e-01, -1.97932005e+00, -3.33335686e+00, -1.85442226e+00,
#        -1.42845973e+00, -2.77098073e+00, -1.70015178e+00, -2.63753114e+00,
#        -2.20996686e+00, -3.24839081e+00, -1.77527350e+00, -2.23480962e+00,
#        -2.42827970e+00, -2.01208493e+00, -2.15837385e+00, -2.11657253e+00,
#        -1.79871395e+00, -1.82843682e+00, -2.18319796e+00, -2.02043208e+00,
#        -7.77400480e-01, -1.41509076e+00, -2.75911127e+00, -2.52328450e+00,
#        -2.28860569e+00, -2.30932466e+00, -1.43145658e+00, -1.97563290e+00,
#        -2.47177161e+00, -1.76517860e+00, -4.33482436e-01, -2.42410033e+00,
#        -1.87558368e+00, -2.71997905e+00, -1.66328262e+00, -2.24041603e+00,
#        -1.90084503e+00, -2.11694722e+00, -1.89838059e+00, -2.67726850e+00,
#        -2.40645805e+00, -3.13916847e+00, -2.16109964e+00, -2.40150793e+00,
#        -3.42738525e+00, -2.76961512e+00, -2.66485658e+00, -3.38718793e+00,
#        -3.29061042e+00, -2.96988966e+00, -2.57654002e+00, -2.51897257e+00,
#        -2.55874713e+00, -2.71713192e+00, -2.65983234e+00, -2.94383111e+00,
#        -2.34669346e+00, -1.65336345e+00, -4.32102375e+00, -3.02788324e+00,
#        -2.71286911e+00, -3.13740531e+00, -3.29601191e+00, -3.89049544e+00,
#        -3.65786867e+00, -2.75734492e+00, -3.08223858e+00, -3.45938874e+00,
#        -2.44707493e+00, -3.80572539e+00, -2.37802062e+00, -3.41994050e+00,
#        -2.70486244e+00, -2.81000835e+00, -2.70134111e+00, -2.24516768e+00,
#        -2.87566382e+00, -2.06008438e+00, -3.52389814e+00, -2.41493355e+00,
#        -3.10334301e+00, -2.97681774e+00, -3.15078123e+00, -3.21773296e+00,
#        -3.59020051e+00, -3.35993485e+00, -2.59124549e+00, -3.35455207e+00,
#        -2.44102870e+00, -3.72870349e+00, -2.61145080e+00, -3.34030105e+00,
#        -4.15148811e+00, -5.28435234e+00, -4.06501235e+00, -4.48538258e+00,
#        -5.40808538e+00, -4.36200740e+00, -3.23193467e+00, -5.23762613e+00,
#        -4.73846740e+00, -3.50247049e+00, -4.56464665e+00, -3.96904745e+00,
#        -4.69543204e+00, -4.73012575e+00, -4.03808191e+00, -3.66275256e+00,
#        -3.94977746e+00, -5.02246330e+00, -4.66619188e+00, -4.02775744e+00,
#        -3.80041857e+00, -4.70584861e+00, -4.72525094e+00, -3.28841878e+00,
#        -5.03275653e+00, -3.83440492e+00, -4.68832003e+00, -4.55758467e+00,
#        -4.35747479e+00, -3.91783745e+00, -4.28298253e+00, -5.51375138e+00,
#        -6.00869332e+00, -5.39270792e+00, -4.86363558e+00, -2.72296140e+00,
#        -4.70043929e+00, -5.10830056e+00, -4.55327531e+00, -4.60727328e+00,
#        -5.83898516e+00, -4.40265295e+00, -4.74482013e+00, -5.48256514e+00,
#        -7.12594093e+00, -6.35510597e+00, -6.25924970e+00, -6.68112278e+00,
#        -5.95106461e+00, -6.19105319e+00, -5.68247880e+00, -6.23382025e+00,
#        -7.74241014e+00, -7.29242229e+00, -7.18096338e+00, -7.21295615e+00,
#        -7.62343076e+00, -7.94092172e+00, -8.70361173e+00, -7.68508481e+00,
#        -1.43199236e-01,  1.81530350e-01,  3.62441632e-01, -5.55683226e-02,
#        -1.41200054e+00, -6.33242629e-01, -9.30377800e-01, -9.06448046e-01,
#        -2.09966777e+00, -7.22178153e-01, -8.85142512e-01, -6.97199997e-01,
#        -7.69407595e-01, -1.94303295e+00, -1.53752679e+00, -1.70409666e+00,
#        -9.10221912e-01,  2.32332538e-02, -1.60905418e+00, -8.59191559e-01,
#        -3.59314344e+00, -2.19486011e+00, -1.45826064e+00, -1.89474158e+00,
#        -6.36569645e-01, -1.84597932e+00, -1.75395639e+00, -1.92707600e+00,
#        -9.57229619e-01, -5.44859482e-01, -1.83293778e+00, -1.26194404e+00,
#        -1.19357020e+00, -2.21577157e+00, -2.34949381e+00, -2.61055211e+00,
#        -2.40569524e+00, -4.42561472e+00, -2.63749133e+00, -5.82991140e-01,
#        -3.64658815e-01, -1.56813896e+00, -4.36769807e+00, -1.42298101e+00,
#        -2.27245612e+00, -2.33148136e+00, -2.60204177e+00, -3.04600260e+00,
#        -2.11947661e+00, -1.54720346e+00, -2.35557849e+00, -2.35792619e+00,
#        -2.64226851e+00, -3.52516237e+00, -2.74292377e+00, -3.23970408e+00,
#        -3.10694255e+00, -3.72569370e+00, -3.15869662e+00, -3.13936933e+00,
#        -3.52630861e+00, -2.70488684e+00, -3.73985104e+00, -3.03310977e+00,
#        -2.55200746e+00, -4.02053300e+00, -4.31315554e+00, -3.82792449e+00,
#        -3.98922862e+00, -3.78762588e+00, -3.18590820e+00, -3.05805319e+00,
#        -4.17472598e+00, -4.66239783e+00, -3.84652843e+00, -4.55525944e+00,
#        -3.36932179e+00, -4.85954828e+00, -4.37213940e+00, -4.00124069e+00,
#        -3.99372725e+00, -3.79059057e+00, -4.73159325e+00, -5.81603008e+00,
#        -5.54099358e+00, -5.57091065e+00, -6.52398360e+00, -5.31438451e+00,
#        -5.87496713e+00, -6.72457908e+00, -7.52757449e+00, -8.23732537e+00,
#        -8.92621537e+00, -9.55348752e+00, -9.31305635e+00, -7.07119019e+00,
#        -2.14793227e+00, -2.94068992e+00, -4.82138585e+00, -4.03954737e+00])

# %% [markdown]
# Usando a função do scikit-learn que calcula o OLS para comparar com o método feito do zero

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
linear_reg_scikitlearn = LinearRegression()
linear_reg_scikitlearn.fit(X_train, y_train)
y_predict_SL = linear_reg_scikitlearn.predict(X_test)

y_predict_SL
# Out:
# array([ 1.13656005e+00,  2.63763233e-02, -3.87234498e-01,  1.02979072e+00,
#        -2.16771083e-01,  1.53759578e+00,  7.07452677e-01,  8.99405219e-01,
#         2.89154032e-01, -5.28659120e-01, -3.62597414e-01, -9.70555805e-01,
#         2.04087691e-02, -2.02037546e-01, -6.79368214e-01, -4.17821304e-01,
#        -1.49623628e-01,  3.75887725e-01,  3.87078013e-01, -6.44964234e-01,
#         5.68256185e-01,  2.89179822e-01, -7.00929389e-01,  2.40269030e-02,
#        -9.88190198e-01,  1.21503325e-01, -7.42279339e-01,  1.26012108e+00,
#        -1.98603201e+00, -1.10581023e+00, -2.58709442e+00, -9.67921570e-01,
#        -6.76775479e-01, -1.44209680e-01, -8.45623386e-02, -1.27108641e+00,
#         2.58724160e-01, -5.87408605e-01, -5.69394008e-03, -6.18591772e-01,
#        -8.01166732e-01, -2.17929875e+00, -1.09172890e+00, -1.59081459e-01,
#        -1.67209854e+00, -7.99278671e-01, -7.11684860e-01, -8.72236630e-01,
#        -1.19216887e+00, -9.56905713e-01,  8.51590148e-01, -1.68812277e+00,
#        -1.45826064e+00, -1.51643055e+00, -2.17389361e+00, -1.27688658e+00,
#        -1.08310895e+00, -1.52196612e+00, -1.82523095e+00, -1.40794907e+00,
#        -1.15286965e+00, -1.32639432e+00, -8.84909908e-01, -1.24153607e+00,
#        -9.55047829e-01, -1.97932005e+00, -3.33335686e+00, -1.85442226e+00,
#        -1.42845973e+00, -2.77098073e+00, -1.70015178e+00, -2.63753114e+00,
#        -2.20996686e+00, -3.24839081e+00, -1.77527350e+00, -2.23480962e+00,
#        -2.42827970e+00, -2.01208493e+00, -2.15837385e+00, -2.11657253e+00,
#        -1.79871394e+00, -1.82843682e+00, -2.18319796e+00, -2.02043208e+00,
#        -7.77400479e-01, -1.41509076e+00, -2.75911127e+00, -2.52328450e+00,
#        -2.28860569e+00, -2.30932466e+00, -1.43145658e+00, -1.97563290e+00,
#        -2.47177161e+00, -1.76517859e+00, -4.33482433e-01, -2.42410032e+00,
#        -1.87558368e+00, -2.71997905e+00, -1.66328262e+00, -2.24041602e+00,
#        -1.90084503e+00, -2.11694721e+00, -1.89838059e+00, -2.67726849e+00,
#        -2.40645805e+00, -3.13916847e+00, -2.16109964e+00, -2.40150793e+00,
#        -3.42738528e+00, -2.76961514e+00, -2.66485658e+00, -3.38718793e+00,
#        -3.29061042e+00, -2.96988967e+00, -2.57654005e+00, -2.51897257e+00,
#        -2.55874716e+00, -2.71713192e+00, -2.65983236e+00, -2.94383111e+00,
#        -2.34669346e+00, -1.65336345e+00, -4.32102375e+00, -3.02788324e+00,
#        -2.71286911e+00, -3.13740531e+00, -3.29601190e+00, -3.89049544e+00,
#        -3.65786867e+00, -2.75734492e+00, -3.08223858e+00, -3.45938874e+00,
#        -2.44707492e+00, -3.80572539e+00, -2.37802062e+00, -3.41994050e+00,
#        -2.70486244e+00, -2.81000835e+00, -2.70134111e+00, -2.24516768e+00,
#        -2.87566382e+00, -2.06008438e+00, -3.52389814e+00, -2.41493355e+00,
#        -3.10334301e+00, -2.97681774e+00, -3.15078125e+00, -3.21773296e+00,
#        -3.59020051e+00, -3.35993485e+00, -2.59124549e+00, -3.35455210e+00,
#        -2.44102870e+00, -3.72870349e+00, -2.61145080e+00, -3.34030105e+00,
#        -4.15148811e+00, -5.28435236e+00, -4.06501235e+00, -4.48538257e+00,
#        -5.40808538e+00, -4.36200740e+00, -3.23193469e+00, -5.23762613e+00,
#        -4.73846740e+00, -3.50247049e+00, -4.56464667e+00, -3.96904745e+00,
#        -4.69543204e+00, -4.73012575e+00, -4.03808193e+00, -3.66275256e+00,
#        -3.94977746e+00, -5.02246330e+00, -4.66619188e+00, -4.02775744e+00,
#        -3.80041857e+00, -4.70584861e+00, -4.72525094e+00, -3.28841878e+00,
#        -5.03275652e+00, -3.83440492e+00, -4.68832003e+00, -4.55758466e+00,
#        -4.35747479e+00, -3.91783745e+00, -4.28298252e+00, -5.51375140e+00,
#        -6.00869332e+00, -5.39270792e+00, -4.86363558e+00, -2.72296139e+00,
#        -4.70043929e+00, -5.10830056e+00, -4.55327531e+00, -4.60727328e+00,
#        -5.83898516e+00, -4.40265295e+00, -4.74482013e+00, -5.48256515e+00,
#        -7.12594093e+00, -6.35510597e+00, -6.25924970e+00, -6.68112278e+00,
#        -5.95106461e+00, -6.19105318e+00, -5.68247882e+00, -6.23382025e+00,
#        -7.74241014e+00, -7.29242229e+00, -7.18096338e+00, -7.21295615e+00,
#        -7.62343076e+00, -7.94092172e+00, -8.70361173e+00, -7.68508480e+00,
#        -1.43199235e-01,  1.81530350e-01,  3.62441609e-01, -5.55683215e-02,
#        -1.41200054e+00, -6.33242628e-01, -9.30377798e-01, -9.06448045e-01,
#        -2.09966777e+00, -7.22178153e-01, -8.85142511e-01, -6.97199995e-01,
#        -7.69407593e-01, -1.94303295e+00, -1.53752679e+00, -1.70409666e+00,
#        -9.10221910e-01,  2.32332557e-02, -1.60905418e+00, -8.59191557e-01,
#        -3.59314346e+00, -2.19486011e+00, -1.45826064e+00, -1.89474158e+00,
#        -6.36569644e-01, -1.84597934e+00, -1.75395639e+00, -1.92707602e+00,
#        -9.57229617e-01, -5.44859481e-01, -1.83293778e+00, -1.26194404e+00,
#        -1.19357020e+00, -2.21577157e+00, -2.34949380e+00, -2.61055211e+00,
#        -2.40569524e+00, -4.42561474e+00, -2.63749135e+00, -5.82991140e-01,
#        -3.64658812e-01, -1.56813895e+00, -4.36769807e+00, -1.42298103e+00,
#        -2.27245612e+00, -2.33148136e+00, -2.60204177e+00, -3.04600260e+00,
#        -2.11947661e+00, -1.54720347e+00, -2.35557848e+00, -2.35792618e+00,
#        -2.64226851e+00, -3.52516237e+00, -2.74292377e+00, -3.23970408e+00,
#        -3.10694257e+00, -3.72569370e+00, -3.15869662e+00, -3.13936932e+00,
#        -3.52630861e+00, -2.70488684e+00, -3.73985104e+00, -3.03310976e+00,
#        -2.55200746e+00, -4.02053300e+00, -4.31315554e+00, -3.82792448e+00,
#        -3.98922862e+00, -3.78762591e+00, -3.18590820e+00, -3.05805320e+00,
#        -4.17472598e+00, -4.66239783e+00, -3.84652842e+00, -4.55525944e+00,
#        -3.36932179e+00, -4.85954828e+00, -4.37213939e+00, -4.00124068e+00,
#        -3.99372724e+00, -3.79059057e+00, -4.73159325e+00, -5.81603008e+00,
#        -5.54099359e+00, -5.57091064e+00, -6.52398360e+00, -5.31438451e+00,
#        -5.87496712e+00, -6.72457908e+00, -7.52757449e+00, -8.23732537e+00,
#        -8.92621537e+00, -9.55348751e+00, -9.31305634e+00, -7.07119019e+00,
#        -2.14793227e+00, -2.94068991e+00, -4.82138585e+00, -4.03954737e+00])

# %% [markdown]
# Criando o cross validation

# %%
def cross_validation(K, X_train, y_train):
    erros_rmse = []
    r2_fold = []
    tam_passo = len(X_train) // K

    for i in range(K):
        # Organizando os índices da fatia
        inicio = i * tam_passo
        fim = (i+1) * tam_passo

        X_test_fold = X_train[inicio:fim]
        y_test_fold = y_train[inicio:fim]

        # Salvando os índices onde o conjunto de testes está, para depois remover os índices do conjunto e criar o conjunto de treinamento
        indices = np.arange(inicio, fim)

        # Criando os conjuntos de treinamento
        X_train_fold = np.delete(X_train, indices, axis=0)
        y_train_fold = np.delete(y_train, indices, axis=0)

        X_train_fold_new = np.c_[np.ones((X_train_fold.shape[0], 1)), X_train_fold]
        betas_fold = OLS(X_train_fold_new, y_train_fold)

        X_test_fold_new = np.c_[np.ones((X_test_fold.shape[0], 1)), X_test_fold]

        y_pred = X_test_fold_new @ betas_fold

        # Calculando o RMSE

        erro = y_test_fold - y_pred
        mse = np.mean(erro ** 2)
        rmse = np.sqrt(mse)

        erros_rmse.append(rmse)

        # Calculando o R^2 (Coeficiente de Determinação)

        sqr = np.sum((y_test_fold - y_pred) ** 2)
        sqt = np.sum((y_test_fold - np.mean(y_test_fold)) ** 2)
        r2 = 1 - (sqr / sqt)

        r2_fold.append(r2)
        
    
    media_RMSE = np.mean(erros_rmse)
    media_Rsquared = np.mean(r2_fold)

    return media_RMSE, media_Rsquared

# %%
media_rmse, media_Rsquared = cross_validation(5, X_train, y_train)

print(media_rmse)

print(media_Rsquared)
# Out:
# 0.8251970936348603
# 0.25611450215590076

# %% [markdown]
# Cross-Validation com scikit-learn

# %% [markdown]
# RMSE

# %%
# Cross-Validation com k = 5 (Calculando o RMSE)
cross_validation_RMSE_sk_5 = cross_val_score(linear_reg_scikitlearn, X_train, y_train, cv=5, scoring='neg_root_mean_squared_error')

media_rmse_sklearn_5 = -1 * cross_validation_RMSE_sk_5.mean() # sklearn devolve o valor negativo

print(media_rmse_sklearn_5)

# Cross-Validation com k = 10 (Calculando o RMSE)
cross_validation_RMSE_sk_10 = cross_val_score(linear_reg_scikitlearn, X_train, y_train, cv=10, scoring='neg_root_mean_squared_error')

media_rmse_sklearn_10 = -1 * cross_validation_RMSE_sk_10.mean() # sklearn devolve o valor negativo

print(media_rmse_sklearn_10)
# Out:
# 0.825707982087688
# 0.7618310852432757

# %% [markdown]
# R-SQUARED

# %%
# Cross-Validation com k = 5 (Calculando o R-squared)
cross_validation_Rsquared_sk_5 = cross_val_score(linear_reg_scikitlearn, X_train, y_train, cv=5, scoring='r2')

media_r2_sklearn = cross_validation_Rsquared_sk_5.mean()

media_r2_sklearn
# Out:
# 0.25641884167318574
